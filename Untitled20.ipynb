# %%
import pandas
df = pandas.read_csv('C:/Users/HP/Desktop/Consumer_Complaints.csv')
print(df)
# Out:
#         Date received                                            Product  \
# 0           3/12/2014                                           Mortgage
# 1           1/19/2017                                       Student loan
# 2            4/6/2018                        Credit card or prepaid card
# 3            6/8/2014                                        Credit card
# 4           9/13/2014                                    Debt collection
# 5          11/13/2013                                           Mortgage
# 6           6/16/2015                                    Debt collection
# 7           8/22/2018                                           Mortgage
# 8          11/13/2015                                           Mortgage
# 9          10/21/2014                                           Mortgage
# 10          4/14/2017                                           Mortgage
# 11          3/30/2012                                       Student loan
# ...

# %%
#customerfeedback = df(usecols=['Consumer complaint narrative','Product'])
customerfeedback = pandas.read_csv('C:/Users/HP/Desktop/Consumer_Complaints.csv', usecols=['Consumer complaint narrative','Product'], encoding='utf-8')
cf=customerfeedback.dropna()

# %%
wellsfargo = pandas.read_csv('C:/Users/HP/Desktop/wellsfargocustcomplaint.csv', encoding='utf-8')

# %%
import matplotlib
pandas.value_counts(wellsfargo['State']).plot.bar(figsize=(15, 5))

# %%
bofa = pandas.read_csv('C:/Users/HP/Desktop/bofacustcomplaint.csv', encoding='utf-8')
pandas.value_counts(bofa['State']).plot.bar(figsize=(15, 5))

# %%
equifax = pandas.read_csv('C:/Users/HP/Desktop/equifaxcustcomplaint.csv', encoding='utf-8')
pandas.value_counts(equifax['State']).plot.bar(figsize=(15, 5))
